# %% [markdown]
# # Como muestrear una PDF

# %%
# Aqui cargamos las liberias a usar

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import scipy.special
from scipy.stats import norm
import numpy as np
import math
from scipy.special import erfinv
# %matplotlib inline

# %% [markdown]
# ## Generamos valores para la funcion acumulada de la Distribucion de Gauss

# %%
mu1 = 70
sig1 = 2
h = 0.01

# %%
x1 = np.arange(60, 80, h)
a1 = np.empty(len(x1))
a2 = np.empty(len(x1))
y1 = np.empty(len(x1))

# %%
for i in range(0, len(x1)):
    a1[i] = 0.5 * (1 + math.erf((x1[i] - mu1)/(sig1*math.sqrt(2))))

# %%
plt.plot(x1,a1, 'black', label="CDF NORMAL $μ = 70, σ = 2$")
plt.legend()
plt.xlabel("$H_{0}$")
plt.ylabel("$F(H_{0})$")
# Out:
# Text(0,0.5,'$F(H_{0})$')

# %%
# Evaluamos la funcion inversa del CDF
for j in range(0, len(x1)):
    a2[j] = sig1 * math.sqrt(2) * erfinv(2 * mu1 - 1) + a1[j]

# %%
plt.plot(x1,a2, 'black', label="PDF NORMAL NORMAL $μ = 70, σ = 2$")
plt.legend()
plt.xlabel("$H_{0}$")
plt.ylabel("$P(H_{0})$")
# Out:
# Text(0,0.5,'$P(H_{0})$')

# %%
for j in range(1, len(x1 - 1)):
    y1[j] = (a1[j] - a1[j-1])/(h)

# %%
plt.plot(x1,y1, 'black', label="PDF NORMAL NORMAL $μ = 70, σ = 2$")
plt.legend()
plt.xlabel("$H_{0}$")
plt.ylabel("$P(H_{0})$")
# Out:
# Text(0,0.5,'$P(H_{0})$')
